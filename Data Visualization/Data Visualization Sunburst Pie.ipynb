# %% [markdown]
# ### Using Plotly

# %%
import pandas as pd

data = pd.read_csv('50_Startups.csv')
data.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
import plotly.express as px
fig = px.sunburst(data, path=['R&D Spend', 'Administration', 'Marketing Spend'], values='Profit', color='State')
fig.show()
# Out:
# <div>                            <div id="99c50e60-e950-4761-bf46-cbddccf27e66" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("99c50e60-e950-4761-bf46-cbddccf27e66")) {                    Plotly.newPlot(                        "99c50e60-e950-4761-bf46-cbddccf27e66",                        [{"branchvalues": "total", "customdata": [["New York"], ["Florida"], ["California"], ["Florida"], ["California"], ["New York"], ["Florida"], ["Florida"], ["Florida"], ["New York"], ["Florida"], ["California"], ["New York"], ["California"], ["Florida"], ["California"], ["Florida"], ["Florida"], ["Florida"], ["Florida"], ["New York"], ["New York"], ["California"], ["New York"], ["California"], ["California"], ["California"], ["New York"], ["California"], ["New York"
# ...
